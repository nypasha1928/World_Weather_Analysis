# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
import requests 
from citipy import citipy
from datetime import datetime

# from config import weather_api_key ( a problem with config ??? )
weather_api_key="1069e5c9ff85b0b8841709f2188e9327"
# from config_gmaps import g_key
g_key = "AIzaSyCvOD8lIGP7wuikRcDgpF-mnpL9mUp0lGQ"

# %%
# Generate 2000 random latitudes and longitudes, and zip them as a list of tuples
lats = np.random.uniform(-90.0,90.0, size=2000)
lngs = np.random.uniform(-180.0,180.0,size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
print(cities[:10], 'Generate', len(cities))
# Out:
# ['tsihombe', 'nikolskoye', 'beringovskiy', 'udachnyy', 'busselton', 'moron', 'arraial do cabo', 'qaanaaq', 'vaini', 'east london'] Generate 780

# %%
# Perform an API call with the OpenWeatherMap.

# initial counters for log and sets
record_count = 1 
set_count = 1

city_data = list()
url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

print('Beginning Data Retrieval     ')
print("-----------------------------")


# use enumerate() method to loop index and item simutanously 

for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city # >> This will find the corresponding weather data for the city instead of 
    #finding the weather data for the first part of the city name.
    

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
       # city_description = city_weather["weather"]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime("%Y-%m-%d %H:%M:%S")
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
          # raining info
        try:
            js['weather'][0]['main'] == 'Rain'
            city_rain = js['rain']['3h']
        except:
            city_rain = 0.000

        # snowing info
        try:
            js['weather'][0]['main'] == 'Snow'
            city_snow = js['snow']['3h']
        except:
            city_snow = 0   



    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 1 | nikolskoye
# Processing Record 3 of Set 1 | beringovskiy
# Processing Record 4 of Set 1 | udachnyy
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | moron
# Processing Record 7 of Set 1 | arraial do cabo
# Processing Record 8 of Set 1 | qaanaaq
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | east london
# Processing Record 11 of Set 1 | praxedis guerrero
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | naruja
# Processing Record 14 of Set 1 | iqaluit
# Processing Record 15 of Set 1 | tuktoyaktuk
# Processing Record 16 of Set 1 | new norfolk
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | norman wells
# Processing Record 19 of Set 1 | hanting
# Processing Record 20 of Set 1 | bengkulu
# Processing Record 21 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | sao joao da barra
# Processing Record 24 of Set 1 | bluff
# Processing Record 25 of Set 1 | hengshui
# Processing Record 26 of Set 1 | torbay
# Processing Record 27 of Set 1 | kaitangata
# Processing Record 28 of Set 1 | saint-philippe
# Processing Record 29 of Set 1 | semypolky
# Processing Record 30 of Set 1 | canavieiras
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | la sarre
# Processing Record 33 of Set 1 | sitka
# Processing Record 34 of Set 1 | isangel
# Processing Record 35 of Set 1 | yellowknife
# Processing Record 36 of Set 1 | castro
# Processing Record 37 of Set 1 | mankapur
# Processing Record 38 of Set 1 | salalah
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | puerto ayora
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | sarkand
# Processing Record 43 of Set 1 | kaka
# Processing Record 44 of Set 1 | nichinan
# Processing Record 45 of Set 1 | jamame
# Processing Record 46 of Set 1 | chubbuck
# Processing Record 47 of Set 1 | coihaique
# Processing Record 48 of Set 1 | khor
# Processing Record 49 of Set 1 | leningradskiy
# Processing Record 50 of Set 1 | linden
# Processing Record 1 of Set 2 | borba
# Processing Record 2 of Set 2 | guangyuan
# Processing Record 3 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 2 | leshukonskoye
# Processing Record 5 of Set 2 | bukachacha
# Processing Record 6 of Set 2 | jiexiu
# Processing Record 7 of Set 2 | san clemente
# Processing Record 8 of Set 2 | tarauaca
# Processing Record 9 of Set 2 | hobart
# Processing Record 10 of Set 2 | elizabeth city
# Processing Record 11 of Set 2 | victoria
# Processing Record 12 of Set 2 | hermanus
# Processing Record 13 of Set 2 | pisco
# Processing Record 14 of Set 2 | itoman
# Processing Record 15 of Set 2 | saint george
# Processing Record 16 of Set 2 | punta arenas
# Processing Record 17 of Set 2 | hambantota
# Processing Record 18 of Set 2 | praya
# Processing Record 19 of Set 2 | thompson
# Processing Record 20 of Set 2 | talawdi
# City not found. Skipping...
# Processing Record 21 of Set 2 | kapaa
# Processing Record 22 of Set 2 | nortelandia
# Processing Record 23 of Set 2 | mar del plata
# Processing Record 24 of Set 2 | ribeira grande
# Processing Record 25 of Set 2 | barrow
# Processing Record 26 of Set 2 | beaufort
# Processing Record 27 of Set 2 | nishihara
# Processing Record 28 of Set 2 | ancud
# Processing Record 29 of Set 2 | gracac
# Processing Record 30 of Set 2 | beloha
# Processing Record 31 of Set 2 | port lincoln
# Processing Record 32 of Set 2 | kloulklubed
# Processing Record 33 of Set 2 | zhicheng
# Processing Record 34 of Set 2 | onega
# Processing Record 35 of Set 2 | pacific grove
# Processing Record 36 of Set 2 | chokurdakh
# Processing Record 37 of Set 2 | muros
# Processing Record 38 of Set 2 | dudinka
# Processing Record 39 of Set 2 | itambe
# Processing Record 40 of Set 2 | jiroft
# City not found. Skipping...
# Processing Record 41 of Set 2 | berlevag
# Processing Record 42 of Set 2 | atuona
# Processing Record 43 of Set 2 | henties bay
# Processing Record 44 of Set 2 | cabo san lucas
# Processing Record 45 of Set 2 | hamilton
# Processing Record 46 of Set 2 | upernavik
# Processing Record 47 of Set 2 | cidreira
# Processing Record 48 of Set 2 | breves
# Processing Record 49 of Set 2 | amapa
# Processing Record 50 of Set 2 | pandrup
# Processing Record 1 of Set 3 | grindavik
# Processing Record 2 of Set 3 | bandarbeyla
# Processing Record 3 of Set 3 | provideniya
# Processing Record 4 of Set 3 | port hardy
# Processing Record 5 of Set 3 | avarua
# Processing Record 6 of Set 3 | chuy
# Processing Record 7 of Set 3 | san patricio
# Processing Record 8 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 9 of Set 3 | yarim
# Processing Record 10 of Set 3 | kempten
# Processing Record 11 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 3 | krasnoslobodsk
# Processing Record 13 of Set 3 | cape town
# Processing Record 14 of Set 3 | kodiak
# Processing Record 15 of Set 3 | innisfail
# Processing Record 16 of Set 3 | lira
# Processing Record 17 of Set 3 | iquique
# Processing Record 18 of Set 3 | ushuaia
# Processing Record 19 of Set 3 | kavieng
# Processing Record 20 of Set 3 | hofn
# Processing Record 21 of Set 3 | yomitan
# City not found. Skipping...
# Processing Record 22 of Set 3 | pochutla
# Processing Record 23 of Set 3 | cam pha
# City not found. Skipping...
# Processing Record 24 of Set 3 | qasigiannguit
# Processing Record 25 of Set 3 | russell
# Processing Record 26 of Set 3 | corrente
# Processing Record 27 of Set 3 | carnarvon
# Processing Record 28 of Set 3 | avera
# Processing Record 29 of Set 3 | tasiilaq
# Processing Record 30 of Set 3 | the valley
# Processing Record 31 of Set 3 | rodopolis
# Processing Record 32 of Set 3 | cherskiy
# Processing Record 33 of Set 3 | lazaro cardenas
# Processing Record 34 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 35 of Set 3 | debre sina
# Processing Record 36 of Set 3 | tilichiki
# Processing Record 37 of Set 3 | port augusta
# Processing Record 38 of Set 3 | bambous virieux
# Processing Record 39 of Set 3 | makurdi
# Processing Record 40 of Set 3 | maltahohe
# Processing Record 41 of Set 3 | gilbues
# Processing Record 42 of Set 3 | rosetta
# Processing Record 43 of Set 3 | lompoc
# Processing Record 44 of Set 3 | mugumu
# Processing Record 45 of Set 3 | sur
# Processing Record 46 of Set 3 | khatanga
# Processing Record 47 of Set 3 | villazon
# Processing Record 48 of Set 3 | codrington
# Processing Record 49 of Set 3 | rawson
# Processing Record 50 of Set 3 | milevsko
# Processing Record 1 of Set 4 | narsaq
# Processing Record 2 of Set 4 | guerrero negro
# Processing Record 3 of Set 4 | atambua
# Processing Record 4 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 5 of Set 4 | tomatlan
# Processing Record 6 of Set 4 | matamoros
# Processing Record 7 of Set 4 | khash
# Processing Record 8 of Set 4 | hithadhoo
# Processing Record 9 of Set 4 | butaritari
# Processing Record 10 of Set 4 | moussoro
# Processing Record 11 of Set 4 | saint-augustin
# Processing Record 12 of Set 4 | namwala
# Processing Record 13 of Set 4 | vondrozo
# Processing Record 14 of Set 4 | mount gambier
# Processing Record 15 of Set 4 | itarema
# Processing Record 16 of Set 4 | pevek
# Processing Record 17 of Set 4 | bara
# Processing Record 18 of Set 4 | puerto colombia
# Processing Record 19 of Set 4 | deer lake
# Processing Record 20 of Set 4 | lagoa
# Processing Record 21 of Set 4 | vardo
# Processing Record 22 of Set 4 | bronkhorstspruit
# Processing Record 23 of Set 4 | vanimo
# Processing Record 24 of Set 4 | asau
# Processing Record 25 of Set 4 | torit
# Processing Record 26 of Set 4 | bayji
# Processing Record 27 of Set 4 | wamba
# Processing Record 28 of Set 4 | constitucion
# Processing Record 29 of Set 4 | luwuk
# Processing Record 30 of Set 4 | pombia
# Processing Record 31 of Set 4 | korla
# Processing Record 32 of Set 4 | sorsk
# Processing Record 33 of Set 4 | itaituba
# Processing Record 34 of Set 4 | port pirie
# Processing Record 35 of Set 4 | raga
# Processing Record 36 of Set 4 | margate
# Processing Record 37 of Set 4 | georgetown
# Processing Record 38 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 4 | tura
# Processing Record 40 of Set 4 | suamico
# Processing Record 41 of Set 4 | esperance
# Processing Record 42 of Set 4 | porosozero
# Processing Record 43 of Set 4 | chekhov
# Processing Record 44 of Set 4 | lebu
# Processing Record 45 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 4 | dunedin
# Processing Record 47 of Set 4 | bud
# Processing Record 48 of Set 4 | saskylakh
# Processing Record 49 of Set 4 | gamba
# Processing Record 50 of Set 4 | mahebourg
# Processing Record 1 of Set 5 | kerzhenets
# City not found. Skipping...
# Processing Record 2 of Set 5 | san policarpo
# Processing Record 3 of Set 5 | caravelas
# Processing Record 4 of Set 5 | lasa
# Processing Record 5 of Set 5 | tautira
# Processing Record 6 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 5 | cockburn town
# Processing Record 8 of Set 5 | klaksvik
# Processing Record 9 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 5 | sao filipe
# Processing Record 12 of Set 5 | lorengau
# Processing Record 13 of Set 5 | haines junction
# Processing Record 14 of Set 5 | saint-leu
# Processing Record 15 of Set 5 | ureki
# Processing Record 16 of Set 5 | hasaki
# Processing Record 17 of Set 5 | teguldet
# Processing Record 18 of Set 5 | nemuro
# Processing Record 19 of Set 5 | thap than
# Processing Record 20 of Set 5 | salym
# Processing Record 21 of Set 5 | valdivia
# Processing Record 22 of Set 5 | luderitz
# Processing Record 23 of Set 5 | morant bay
# Processing Record 24 of Set 5 | saldanha
# Processing Record 25 of Set 5 | gigmoto
# Processing Record 26 of Set 5 | tuatapere
# Processing Record 27 of Set 5 | bethel
# Processing Record 28 of Set 5 | ondjiva
# Processing Record 29 of Set 5 | longyearbyen
# Processing Record 30 of Set 5 | borogontsy
# Processing Record 31 of Set 5 | yialos
# City not found. Skipping...
# Processing Record 32 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 5 | los mochis
# Processing Record 34 of Set 5 | posse
# Processing Record 35 of Set 5 | altay
# Processing Record 36 of Set 5 | doha
# Processing Record 37 of Set 5 | visby
# Processing Record 38 of Set 5 | kalabo
# Processing Record 39 of Set 5 | williams lake
# Processing Record 40 of Set 5 | matay
# Processing Record 41 of Set 5 | igrim
# Processing Record 42 of Set 5 | irbeyskoye
# Processing Record 43 of Set 5 | belmonte
# Processing Record 44 of Set 5 | sena madureira
# Processing Record 45 of Set 5 | levin
# Processing Record 46 of Set 5 | mchinji
# Processing Record 47 of Set 5 | yumen
# Processing Record 48 of Set 5 | conde
# Processing Record 49 of Set 5 | sukhumi
# Processing Record 50 of Set 5 | bose
# Processing Record 1 of Set 6 | pangnirtung
# Processing Record 2 of Set 6 | opuwo
# Processing Record 3 of Set 6 | muroto
# Processing Record 4 of Set 6 | zhangye
# Processing Record 5 of Set 6 | karratha
# Processing Record 6 of Set 6 | cartagena
# Processing Record 7 of Set 6 | igarka
# Processing Record 8 of Set 6 | iranshahr
# Processing Record 9 of Set 6 | ilulissat
# Processing Record 10 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 6 | hilo
# Processing Record 12 of Set 6 | shatrovo
# Processing Record 13 of Set 6 | tateyama
# Processing Record 14 of Set 6 | kadi
# Processing Record 15 of Set 6 | westport
# Processing Record 16 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 6 | buta
# Processing Record 18 of Set 6 | nanortalik
# Processing Record 19 of Set 6 | ambilobe
# Processing Record 20 of Set 6 | bathsheba
# Processing Record 21 of Set 6 | galesong
# Processing Record 22 of Set 6 | cabedelo
# Processing Record 23 of Set 6 | simpang
# Processing Record 24 of Set 6 | san cristobal
# Processing Record 25 of Set 6 | dingle
# Processing Record 26 of Set 6 | trelew
# Processing Record 27 of Set 6 | coos bay
# Processing Record 28 of Set 6 | awassa
# Processing Record 29 of Set 6 | moose factory
# Processing Record 30 of Set 6 | okakarara
# Processing Record 31 of Set 6 | lavrentiya
# Processing Record 32 of Set 6 | terenos
# Processing Record 33 of Set 6 | lubango
# Processing Record 34 of Set 6 | taltal
# Processing Record 35 of Set 6 | praia da vitoria
# Processing Record 36 of Set 6 | meulaboh
# Processing Record 37 of Set 6 | jomalig
# City not found. Skipping...
# Processing Record 38 of Set 6 | samarai
# Processing Record 39 of Set 6 | khabary
# Processing Record 40 of Set 6 | yacuiba
# Processing Record 41 of Set 6 | laguna
# Processing Record 42 of Set 6 | aklavik
# Processing Record 43 of Set 6 | bonfim
# Processing Record 44 of Set 6 | caxito
# Processing Record 45 of Set 6 | kasempa
# Processing Record 46 of Set 6 | adrar
# Processing Record 47 of Set 6 | nome
# Processing Record 48 of Set 6 | payson
# Processing Record 49 of Set 6 | olafsvik
# Processing Record 50 of Set 6 | geraldton
# Processing Record 1 of Set 7 | talara
# Processing Record 2 of Set 7 | morehead
# Processing Record 3 of Set 7 | mantua
# Processing Record 4 of Set 7 | olsztyn
# Processing Record 5 of Set 7 | maria aurora
# Processing Record 6 of Set 7 | praia
# Processing Record 7 of Set 7 | shebunino
# Processing Record 8 of Set 7 | tabas
# Processing Record 9 of Set 7 | dikson
# Processing Record 10 of Set 7 | fallon
# Processing Record 11 of Set 7 | lubumbashi
# Processing Record 12 of Set 7 | svetlyy
# Processing Record 13 of Set 7 | carauari
# Processing Record 14 of Set 7 | komsomolskiy
# Processing Record 15 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 7 | port elizabeth
# Processing Record 17 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 7 | northam
# Processing Record 19 of Set 7 | goderich
# Processing Record 20 of Set 7 | clyde river
# Processing Record 21 of Set 7 | namibe
# Processing Record 22 of Set 7 | airai
# Processing Record 23 of Set 7 | barstow
# Processing Record 24 of Set 7 | fortuna
# Processing Record 25 of Set 7 | solnechnyy
# Processing Record 26 of Set 7 | oudtshoorn
# Processing Record 27 of Set 7 | soyo
# Processing Record 28 of Set 7 | goias
# Processing Record 29 of Set 7 | smolenka
# Processing Record 30 of Set 7 | touros
# Processing Record 31 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 7 | salamiyah
# Processing Record 33 of Set 7 | umm kaddadah
# Processing Record 34 of Set 7 | iquitos
# Processing Record 35 of Set 7 | kurumkan
# Processing Record 36 of Set 7 | vila velha
# Processing Record 37 of Set 7 | crato
# Processing Record 38 of Set 7 | anlu
# Processing Record 39 of Set 7 | aitape
# Processing Record 40 of Set 7 | coquimbo
# Processing Record 41 of Set 7 | sabaudia
# Processing Record 42 of Set 7 | sheridan
# Processing Record 43 of Set 7 | umm durman
# City not found. Skipping...
# Processing Record 44 of Set 7 | fairfield
# Processing Record 45 of Set 7 | labuhan
# Processing Record 46 of Set 7 | port hedland
# Processing Record 47 of Set 7 | marawi
# Processing Record 48 of Set 7 | agoura hills
# Processing Record 49 of Set 7 | kutum
# Processing Record 50 of Set 7 | la libertad
# Processing Record 1 of Set 8 | manta
# Processing Record 2 of Set 8 | bilibino
# Processing Record 3 of Set 8 | houma
# Processing Record 4 of Set 8 | sechura
# Processing Record 5 of Set 8 | beihai
# Processing Record 6 of Set 8 | prince rupert
# Processing Record 7 of Set 8 | mandalgovi
# Processing Record 8 of Set 8 | indiana
# Processing Record 9 of Set 8 | mukhen
# Processing Record 10 of Set 8 | manicore
# Processing Record 11 of Set 8 | razole
# Processing Record 12 of Set 8 | kintampo
# Processing Record 13 of Set 8 | tual
# Processing Record 14 of Set 8 | flinders
# Processing Record 15 of Set 8 | baruun-urt
# Processing Record 16 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 8 | ponta do sol
# Processing Record 18 of Set 8 | jinchang
# Processing Record 19 of Set 8 | aripuana
# Processing Record 20 of Set 8 | srednekolymsk
# Processing Record 21 of Set 8 | thohoyandou
# Processing Record 22 of Set 8 | vestmanna
# Processing Record 23 of Set 8 | qaqortoq
# Processing Record 24 of Set 8 | roald
# Processing Record 25 of Set 8 | fare
# Processing Record 26 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 8 | san carlos de bariloche
# Processing Record 28 of Set 8 | port blair
# Processing Record 29 of Set 8 | chokwe
# Processing Record 30 of Set 8 | yurga
# Processing Record 31 of Set 8 | comodoro rivadavia
# Processing Record 32 of Set 8 | buraydah
# Processing Record 33 of Set 8 | oranjemund
# Processing Record 34 of Set 8 | assiniboia
# Processing Record 35 of Set 8 | kayerkan
# Processing Record 36 of Set 8 | culipapa
# City not found. Skipping...
# Processing Record 37 of Set 8 | roma
# Processing Record 38 of Set 8 | san antonio
# Processing Record 39 of Set 8 | salinas
# Processing Record 40 of Set 8 | buchanan
# Processing Record 41 of Set 8 | husavik
# Processing Record 42 of Set 8 | hami
# Processing Record 43 of Set 8 | alizai
# Processing Record 44 of Set 8 | jaen
# Processing Record 45 of Set 8 | tiksi
# Processing Record 46 of Set 8 | steinbach
# Processing Record 47 of Set 8 | honningsvag
# Processing Record 48 of Set 8 | rakhya
# City not found. Skipping...
# Processing Record 49 of Set 8 | anadyr
# Processing Record 50 of Set 8 | progreso
# Processing Record 1 of Set 9 | bukid
# Processing Record 2 of Set 9 | westpunt
# City not found. Skipping...
# Processing Record 3 of Set 9 | destin
# Processing Record 4 of Set 9 | maloshuyka
# City not found. Skipping...
# Processing Record 5 of Set 9 | evanston
# Processing Record 6 of Set 9 | otane
# Processing Record 7 of Set 9 | zwedru
# Processing Record 8 of Set 9 | bambanglipuro
# Processing Record 9 of Set 9 | yar-sale
# Processing Record 10 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 9 | ostrovnoy
# Processing Record 12 of Set 9 | porto novo
# Processing Record 13 of Set 9 | lyubim
# Processing Record 14 of Set 9 | channel-port aux basques
# Processing Record 15 of Set 9 | saint-pierre
# Processing Record 16 of Set 9 | clarence town
# Processing Record 17 of Set 9 | suileng
# Processing Record 18 of Set 9 | tungkang
# City not found. Skipping...
# Processing Record 19 of Set 9 | seymchan
# Processing Record 20 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 9 | gizo
# Processing Record 22 of Set 9 | inhambane
# Processing Record 23 of Set 9 | asaba
# Processing Record 24 of Set 9 | wundanyi
# Processing Record 25 of Set 9 | maralal
# Processing Record 26 of Set 9 | tamworth
# Processing Record 27 of Set 9 | presidencia roque saenz pena
# Processing Record 28 of Set 9 | nevsehir
# Processing Record 29 of Set 9 | vernon
# Processing Record 30 of Set 9 | circleville
# Processing Record 31 of Set 9 | georgiyevka
# Processing Record 32 of Set 9 | san diego
# Processing Record 33 of Set 9 | acapulco
# Processing Record 34 of Set 9 | nago
# Processing Record 35 of Set 9 | saint anthony
# Processing Record 36 of Set 9 | raudeberg
# Processing Record 37 of Set 9 | sorong
# Processing Record 38 of Set 9 | benemerito de las americas
# Processing Record 39 of Set 9 | padang
# Processing Record 40 of Set 9 | maragogi
# Processing Record 41 of Set 9 | dongsheng
# Processing Record 42 of Set 9 | pilot butte
# Processing Record 43 of Set 9 | waddan
# Processing Record 44 of Set 9 | mwene-ditu
# Processing Record 45 of Set 9 | syedove
# Processing Record 46 of Set 9 | arona
# Processing Record 47 of Set 9 | aksu
# Processing Record 48 of Set 9 | puerto madryn
# Processing Record 49 of Set 9 | richards bay
# Processing Record 50 of Set 9 | paita
# Processing Record 1 of Set 10 | golcuv jenikov
# Processing Record 2 of Set 10 | severo-kurilsk
# Processing Record 3 of Set 10 | bonthe
# Processing Record 4 of Set 10 | lata
# Processing Record 5 of Set 10 | bar-le-duc
# Processing Record 6 of Set 10 | cayenne
# Processing Record 7 of Set 10 | taurianova
# Processing Record 8 of Set 10 | umm lajj
# Processing Record 9 of Set 10 | salamanca
# Processing Record 10 of Set 10 | mackay
# Processing Record 11 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 12 of Set 10 | potsdam
# Processing Record 13 of Set 10 | morondava
# Processing Record 14 of Set 10 | borama
# City not found. Skipping...
# Processing Record 15 of Set 10 | vavoua
# Processing Record 16 of Set 10 | ngunguru
# Processing Record 17 of Set 10 | bubaque
# Processing Record 18 of Set 10 | necochea
# Processing Record 19 of Set 10 | tankhoy
# Processing Record 20 of Set 10 | tupiza
# Processing Record 21 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 10 | rock springs
# Processing Record 23 of Set 10 | pospelikha
# Processing Record 24 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 25 of Set 10 | rajanpur
# Processing Record 26 of Set 10 | larsnes
# Processing Record 27 of Set 10 | phan thiet
# Processing Record 28 of Set 10 | souillac
# Processing Record 29 of Set 10 | mayumba
# Processing Record 30 of Set 10 | burpengary
# Processing Record 31 of Set 10 | paka
# Processing Record 32 of Set 10 | khandyga
# Processing Record 33 of Set 10 | palafrugell
# Processing Record 34 of Set 10 | kerrville
# Processing Record 35 of Set 10 | lucapa
# Processing Record 36 of Set 10 | great yarmouth
# Processing Record 37 of Set 10 | burgthann
# Processing Record 38 of Set 10 | nelson bay
# Processing Record 39 of Set 10 | were ilu
# Processing Record 40 of Set 10 | palana
# Processing Record 41 of Set 10 | thinadhoo
# Processing Record 42 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 10 | mongo
# Processing Record 44 of Set 10 | fukue
# Processing Record 45 of Set 10 | atar
# Processing Record 46 of Set 10 | ust-ilimsk
# Processing Record 47 of Set 10 | tezu
# Processing Record 48 of Set 10 | suffolk
# Processing Record 49 of Set 10 | kaihua
# Processing Record 50 of Set 10 | sulangan
# Processing Record 1 of Set 11 | vaitape
# Processing Record 2 of Set 11 | las vegas
# Processing Record 3 of Set 11 | seoul
# Processing Record 4 of Set 11 | lerdo
# Processing Record 5 of Set 11 | portland
# Processing Record 6 of Set 11 | marzuq
# Processing Record 7 of Set 11 | iskateley
# Processing Record 8 of Set 11 | bajo baudo
# City not found. Skipping...
# Processing Record 9 of Set 11 | pathanamthitta
# Processing Record 10 of Set 11 | bull savanna
# Processing Record 11 of Set 11 | abu dhabi
# Processing Record 12 of Set 11 | maura
# Processing Record 13 of Set 11 | bhadrachalam
# Processing Record 14 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 15 of Set 11 | voh
# Processing Record 16 of Set 11 | senanga
# Processing Record 17 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 18 of Set 11 | inuvik
# Processing Record 19 of Set 11 | tarhunah
# City not found. Skipping...
# Processing Record 20 of Set 11 | saint-joseph
# Processing Record 21 of Set 11 | erenhot
# Processing Record 22 of Set 11 | araouane
# Processing Record 23 of Set 11 | mormugao
# Processing Record 24 of Set 11 | faya
# Processing Record 25 of Set 11 | san pedro
# Processing Record 26 of Set 11 | proddatur
# Processing Record 27 of Set 11 | ciras
# City not found. Skipping...
# Processing Record 28 of Set 11 | riyadh
# Processing Record 29 of Set 11 | czluchow
# Processing Record 30 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 31 of Set 11 | fenoarivo atsinanana
# Processing Record 32 of Set 11 | killybegs
# Processing Record 33 of Set 11 | felipe carrillo puerto
# Processing Record 34 of Set 11 | kokologo
# Processing Record 35 of Set 11 | byron bay
# Processing Record 36 of Set 11 | batagay-alyta
# Processing Record 37 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 11 | kahului
# Processing Record 39 of Set 11 | mitsamiouli
# Processing Record 40 of Set 11 | sibut
# Processing Record 41 of Set 11 | zaragoza
# Processing Record 42 of Set 11 | ta khmau
# Processing Record 43 of Set 11 | ulladulla
# Processing Record 44 of Set 11 | vila do maio
# Processing Record 45 of Set 11 | ghanzi
# Processing Record 46 of Set 11 | pitimbu
# Processing Record 47 of Set 11 | arman
# Processing Record 48 of Set 11 | hokitika
# Processing Record 49 of Set 11 | guisa
# Processing Record 50 of Set 11 | tecoanapa
# Processing Record 1 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 12 | wewak
# Processing Record 3 of Set 12 | tazovskiy
# Processing Record 4 of Set 12 | basco
# Processing Record 5 of Set 12 | gladstone
# Processing Record 6 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 12 | taoudenni
# Processing Record 8 of Set 12 | yulara
# Processing Record 9 of Set 12 | nanakuli
# Processing Record 10 of Set 12 | merauke
# Processing Record 11 of Set 12 | namatanai
# Processing Record 12 of Set 12 | sucua
# Processing Record 13 of Set 12 | darhan
# Processing Record 14 of Set 12 | yaya
# Processing Record 15 of Set 12 | sosnovoborsk
# Processing Record 16 of Set 12 | arlit
# Processing Record 17 of Set 12 | worthington
# Processing Record 18 of Set 12 | grants pass
# Processing Record 19 of Set 12 | santo angelo
# Processing Record 20 of Set 12 | bodden town
# Processing Record 21 of Set 12 | mabaruma
# Processing Record 22 of Set 12 | puerto escondido
# Processing Record 23 of Set 12 | uchiza
# Processing Record 24 of Set 12 | bayir
# Processing Record 25 of Set 12 | shingu
# Processing Record 26 of Set 12 | baykit
# Processing Record 27 of Set 12 | biltine
# Processing Record 28 of Set 12 | noyabrsk
# Processing Record 29 of Set 12 | yerbogachen
# Processing Record 30 of Set 12 | ilhabela
# Processing Record 31 of Set 12 | baker city
# Processing Record 32 of Set 12 | rio brilhante
# Processing Record 33 of Set 12 | sembakung
# Processing Record 34 of Set 12 | kichera
# Processing Record 35 of Set 12 | faanui
# Processing Record 36 of Set 12 | shenjiamen
# Processing Record 37 of Set 12 | dolores
# Processing Record 38 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 39 of Set 12 | kwinana
# Processing Record 40 of Set 12 | alice springs
# Processing Record 41 of Set 12 | kununurra
# Processing Record 42 of Set 12 | quballat
# Processing Record 43 of Set 12 | axim
# Processing Record 44 of Set 12 | seddon
# Processing Record 45 of Set 12 | vilyuysk
# Processing Record 46 of Set 12 | marienburg
# Processing Record 47 of Set 12 | springfield
# Processing Record 48 of Set 12 | micheweni
# Processing Record 49 of Set 12 | yangmei
# Processing Record 50 of Set 12 | stromness
# Processing Record 1 of Set 13 | sampit
# Processing Record 2 of Set 13 | las cruces
# Processing Record 3 of Set 13 | takayama
# Processing Record 4 of Set 13 | antalaha
# Processing Record 5 of Set 13 | tandil
# Processing Record 6 of Set 13 | boa vista
# Processing Record 7 of Set 13 | seljord
# Processing Record 8 of Set 13 | ust-maya
# Processing Record 9 of Set 13 | high level
# Processing Record 10 of Set 13 | chikoy
# City not found. Skipping...
# Processing Record 11 of Set 13 | katsuura
# Processing Record 12 of Set 13 | rangapara
# Processing Record 13 of Set 13 | navolato
# Processing Record 14 of Set 13 | fairbanks
# Processing Record 15 of Set 13 | vigeland
# Processing Record 16 of Set 13 | gat
# Processing Record 17 of Set 13 | skagen
# Processing Record 18 of Set 13 | tarma
# Processing Record 19 of Set 13 | kesinga
# Processing Record 20 of Set 13 | campos belos
# Processing Record 21 of Set 13 | aswan
# Processing Record 22 of Set 13 | la asuncion
# Processing Record 23 of Set 13 | kisangani
# Processing Record 24 of Set 13 | langsa
# Processing Record 25 of Set 13 | jeremie
# Processing Record 26 of Set 13 | kavaratti
# Processing Record 27 of Set 13 | leua
# Processing Record 28 of Set 13 | santa maria
# Processing Record 29 of Set 13 | ayagoz
# Processing Record 30 of Set 13 | alofi
# Processing Record 31 of Set 13 | puerto baquerizo moreno
# Processing Record 32 of Set 13 | usumatlan
# Processing Record 33 of Set 13 | nyrob
# Processing Record 34 of Set 13 | pimenta bueno
# Processing Record 35 of Set 13 | farafangana
# Processing Record 36 of Set 13 | puerto palomas
# Processing Record 37 of Set 13 | oistins
# Processing Record 38 of Set 13 | miragoane
# Processing Record 39 of Set 13 | renqiu
# Processing Record 40 of Set 13 | camacha
# Processing Record 41 of Set 13 | hay river
# Processing Record 42 of Set 13 | angoche
# Processing Record 43 of Set 13 | hovd
# Processing Record 44 of Set 13 | sarangani
# Processing Record 45 of Set 13 | calabozo
# Processing Record 46 of Set 13 | barao de melgaco
# Processing Record 47 of Set 13 | iskitim
# Processing Record 48 of Set 13 | mocuba
# Processing Record 49 of Set 13 | aksarka
# Processing Record 50 of Set 13 | vao
# Processing Record 1 of Set 14 | nabire
# Processing Record 2 of Set 14 | tazmalt
# Processing Record 3 of Set 14 | kemijarvi
# Processing Record 4 of Set 14 | orchard homes
# Processing Record 5 of Set 14 | redmond
# Processing Record 6 of Set 14 | labrea
# Processing Record 7 of Set 14 | otavalo
# Processing Record 8 of Set 14 | galich
# Processing Record 9 of Set 14 | clonakilty
# Processing Record 10 of Set 14 | jalu
# Processing Record 11 of Set 14 | novovarshavka
# Processing Record 12 of Set 14 | kruisfontein
# Processing Record 13 of Set 14 | jaguaribe
# Processing Record 14 of Set 14 | sandwick
# Processing Record 15 of Set 14 | ashdod
# Processing Record 16 of Set 14 | broome
# Processing Record 17 of Set 14 | kaeo
# Processing Record 18 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 19 of Set 14 | camabatela
# Processing Record 20 of Set 14 | sabang
# Processing Record 21 of Set 14 | turukhansk
# Processing Record 22 of Set 14 | nuevo casas grandes
# Processing Record 23 of Set 14 | egvekinot
# Processing Record 24 of Set 14 | dilla
# Processing Record 25 of Set 14 | hirakud
# Processing Record 26 of Set 14 | moerai
# Processing Record 27 of Set 14 | hohhot
# Processing Record 28 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 29 of Set 14 | bell ville
# Processing Record 30 of Set 14 | west wendover
# Processing Record 31 of Set 14 | sao luiz gonzaga
# Processing Record 32 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 33 of Set 14 | yamada
# Processing Record 34 of Set 14 | ormond beach
# Processing Record 35 of Set 14 | neiafu
# Processing Record 36 of Set 14 | nogliki
# Processing Record 37 of Set 14 | gamboma
# Processing Record 38 of Set 14 | san quintin
# Processing Record 39 of Set 14 | am timan
# Processing Record 40 of Set 14 | cedar city
# Processing Record 41 of Set 14 | fort-shevchenko
# Processing Record 42 of Set 14 | francia
# Processing Record 43 of Set 14 | souris
# Processing Record 44 of Set 14 | aykhal
# Processing Record 45 of Set 14 | makaha
# Processing Record 46 of Set 14 | key west
# Processing Record 47 of Set 14 | pontianak
# Processing Record 48 of Set 14 | talnakh
# Processing Record 49 of Set 14 | beyneu
# Processing Record 50 of Set 14 | fort nelson
# Processing Record 1 of Set 15 | maniitsoq
# Processing Record 2 of Set 15 | jabiru
# City not found. Skipping...
# Processing Record 3 of Set 15 | shalakusha
# Processing Record 4 of Set 15 | katherine
# Processing Record 5 of Set 15 | makushino
# Processing Record 6 of Set 15 | shar
# Processing Record 7 of Set 15 | tutoia
# Processing Record 8 of Set 15 | kabinda
# Processing Record 9 of Set 15 | mareeba
# Processing Record 10 of Set 15 | makakilo city
# Processing Record 11 of Set 15 | naze
# Processing Record 12 of Set 15 | ulcinj
# Processing Record 13 of Set 15 | beisfjord
# Processing Record 14 of Set 15 | klyuchi
# Processing Record 15 of Set 15 | baglan
# Processing Record 16 of Set 15 | banes
# Processing Record 17 of Set 15 | dvinskoy
# Processing Record 18 of Set 15 | brae
# Processing Record 19 of Set 15 | glamoc
# Processing Record 20 of Set 15 | ternate
# Processing Record 21 of Set 15 | gairatganj
# Processing Record 22 of Set 15 | sioux lookout
# Processing Record 23 of Set 15 | aguada de pasajeros
# Processing Record 24 of Set 15 | kaabong
# Processing Record 25 of Set 15 | del rio
# Processing Record 26 of Set 15 | bridlington
# Processing Record 27 of Set 15 | leh
# Processing Record 28 of Set 15 | dukat
# Processing Record 29 of Set 15 | waipawa
# Processing Record 30 of Set 15 | tabou
# Processing Record 31 of Set 15 | maassluis
# Processing Record 32 of Set 15 | novikovo
# Processing Record 33 of Set 15 | mogzon
# Processing Record 34 of Set 15 | tungor
# Processing Record 35 of Set 15 | sola
# Processing Record 36 of Set 15 | khanpur
# Processing Record 37 of Set 15 | nouadhibou
# Processing Record 38 of Set 15 | kokopo
# Processing Record 39 of Set 15 | keti bandar
# Processing Record 40 of Set 15 | valparaiso
# Processing Record 41 of Set 15 | darnah
# Processing Record 42 of Set 15 | pahrump
# Processing Record 43 of Set 15 | pagudpud
# Processing Record 44 of Set 15 | wakkanai
# Processing Record 45 of Set 15 | jyvaskyla
# Processing Record 46 of Set 15 | sayyan
# Processing Record 47 of Set 15 | barranca
# Processing Record 48 of Set 15 | deputatskiy
# Processing Record 49 of Set 15 | victor harbor
# Processing Record 50 of Set 15 | kungurtug
# Processing Record 1 of Set 16 | chaykovskaya
# Processing Record 2 of Set 16 | hervey bay
# Processing Record 3 of Set 16 | nakamura
# Processing Record 4 of Set 16 | los llanos de aridane
# Processing Record 5 of Set 16 | edgewater
# Processing Record 6 of Set 16 | presque isle
# Processing Record 7 of Set 16 | zhigansk
# Processing Record 8 of Set 16 | siilinjarvi
# Processing Record 9 of Set 16 | taburi
# City not found. Skipping...
# Processing Record 10 of Set 16 | tobermory
# Processing Record 11 of Set 16 | quatre cocos
# Processing Record 12 of Set 16 | obregon
# Processing Record 13 of Set 16 | sinop
# Processing Record 14 of Set 16 | la ronge
# Processing Record 15 of Set 16 | maryanovka
# City not found. Skipping...
# Processing Record 16 of Set 16 | baglung
# Processing Record 17 of Set 16 | florenville
# Processing Record 18 of Set 16 | mucuri
# Processing Record 19 of Set 16 | teya
# Processing Record 20 of Set 16 | bowen
# Processing Record 21 of Set 16 | avila
# Processing Record 22 of Set 16 | filadelfia
# Processing Record 23 of Set 16 | mount isa
# Processing Record 24 of Set 16 | sinnamary
# Processing Record 25 of Set 16 | lovington
# Processing Record 26 of Set 16 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 16 | vieira de leiria
# Processing Record 28 of Set 16 | bay roberts
# Processing Record 29 of Set 16 | illintsi
# Processing Record 30 of Set 16 | high prairie
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))
# Out:
# 723

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data= pd.DataFrame(city_data)
city_data.head(10)
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Sakaiminato  35.55  133.23     60.80        87          75        9.17
# 1         Coquimbo -29.95  -71.34     55.40        82          75       12.75
# 2          Rikitea -23.12 -134.97     74.62        85          86       22.84
# 3           Atuona  -9.80 -139.03     77.47        79          68       15.12
# 4            Khash  28.22   61.22     40.87        61           0        2.15
# 5      East London -33.02   27.91     65.43        83          73       14.47
# 6           Barrow  71.29 -156.79     28.40        79          90       19.46
# 7  Bambous Virieux -20.34   57.76     69.80        68          40        9.17
# 8     General Roca -39.03  -67.58     89.60        25           0        3.36
# 9             Lata  40.16   -8.33     66.00        92          97        0.69
#
#   Country                 Date
# 0      JP  2020-11-01 23:00:44
# 1      CL  2020-11-01 23:00:44
# 2      PF  2020-11-01 23:00:44
# 3      PF  2020-11-01 23:00:44
# 4      IR  2020-11-01 23:00:44
# 5      ZA  2020-11-01 23:00:44
# 6      US  2020-11-01 22:57:24
# 7      MU  2020-11-01 23:00:45
# 8      AR  2020-11-01 23:00:45
# 9      PT  2020-11-01 23:00:45

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

# %%
city_data = city_data[new_column_order]
city_data
# Out:
#              City Country                 Date    Lat     Lng  Max Temp  \
# 0     Sakaiminato      JP  2020-11-01 23:00:44  35.55  133.23     60.80
# 1        Coquimbo      CL  2020-11-01 23:00:44 -29.95  -71.34     55.40
# 2         Rikitea      PF  2020-11-01 23:00:44 -23.12 -134.97     74.62
# 3          Atuona      PF  2020-11-01 23:00:44  -9.80 -139.03     77.47
# 4           Khash      IR  2020-11-01 23:00:44  28.22   61.22     40.87
# ..            ...     ...                  ...    ...     ...       ...
# 703  Barra Patuca      HN  2020-11-01 22:58:38  15.80  -84.28     79.79
# 704      Lokosovo      RU  2020-11-01 22:58:39  61.13   74.82     29.59
# 705        Curuca      BR  2020-11-01 22:58:39  -0.73  -47.85     78.30
# 706  Fernan-Nunez      ES  2020-11-01 22:58:39  37.69   -4.72     57.20
# 707           Ola      RU  2020-11-01 22:58:39  59.58  151.28     30.06
#
#      Humidity  Cloudiness  Wind Speed
# 0          87          75        9.17
# 1          82          75       12.75
# 2          85          86       22.84
# 3          79          68       15.12
# 4          61           0        2.15
# ..        ...         ...         ...
# 703        85         100        9.51
# 704        97          99       11.83
# 705        84          92        5.64
# 706        82           0        1.12
# 707        93          99        8.32
#
# [708 rows x 9 columns]

# %%
WeatherPy_Database_df = pd.DataFrame(city_data)
WeatherPy_Database_df.to_csv("WeatherPy_Database/WeatherPy_Database.csv", index_label= "city ID")
