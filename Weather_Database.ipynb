# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
import requests 
from citipy import citipy
from datetime import datetime

# from config import weather_api_key ( a problem with config ??? )
weather_api_key="1069e5c9ff85b0b8841709f2188e9327"
# from config_gmaps import g_key
g_key = "AIzaSyCvOD8lIGP7wuikRcDgpF-mnpL9mUp0lGQ"

# %%
# Generate 2000 random latitudes and longitudes, and zip them as a list of tuples
lats = np.random.uniform(-90.0,90.0, size=2000)
lngs = np.random.uniform(-180.0,180.0,size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
print(cities[:10], 'Generate', len(cities))
# Out:
# ['sakaiminato', 'coquimbo', 'rikitea', 'atuona', 'khash', 'east london', 'barrow', 'bambous virieux', 'general roca', 'lata'] Generate 769

# %%
# Perform an API call with the OpenWeatherMap.

# initial counters for log and sets
record_count = 1 
set_count = 1

city_data = list()
url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

print('Beginning Data Retrieval     ')
print("-----------------------------")


# use enumerate() method to loop index and item simutanously 

for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city # >> This will find the corresponding weather data for the city instead of 
    #finding the weather data for the first part of the city name.
    

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime("%Y-%m-%d %H:%M:%S")
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
          # raining info
        try:
            js['weather'][0]['main'] == 'Rain'
            city_rain = js['rain']['3h']
        except:
            city_rain = 0.000

        # snowing info
        try:
            js['weather'][0]['main'] == 'Snow'
            city_snow = js['snow']['3h']
        except:
            city_snow = 0   

#         # append as a list of dictionaries
#         city_data.append({'City':city_name, 'Country':city_country, 'Date':city_date, 
#                         'Lat':city_lat, 'Lng': city_lon,'Max Temp':city_max_temp,
#                         'Humidity':city_humidity,'Cloudiness': city_cload,'Wind Speed':city_wind_speed,
#                         'Current Description':city_weather_description,
#                         'Rain inches (last 3 hrs)':city_rain,'Snow inches (last 3 hrs)':city_snow})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sakaiminato
# Processing Record 2 of Set 1 | coquimbo
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | khash
# Processing Record 6 of Set 1 | east london
# Processing Record 7 of Set 1 | barrow
# Processing Record 8 of Set 1 | bambous virieux
# Processing Record 9 of Set 1 | general roca
# Processing Record 10 of Set 1 | lata
# Processing Record 11 of Set 1 | aquiraz
# Processing Record 12 of Set 1 | kruisfontein
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | nakonde
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | kodiak
# Processing Record 17 of Set 1 | port alfred
# Processing Record 18 of Set 1 | zavodskoy
# Processing Record 19 of Set 1 | carnarvon
# Processing Record 20 of Set 1 | meulaboh
# Processing Record 21 of Set 1 | christchurch
# Processing Record 22 of Set 1 | camacha
# Processing Record 23 of Set 1 | husavik
# Processing Record 24 of Set 1 | bluff
# Processing Record 25 of Set 1 | te anau
# Processing Record 26 of Set 1 | saskylakh
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | yovon
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 1 | constitucion
# Processing Record 32 of Set 1 | uvarovka
# Processing Record 33 of Set 1 | nouadhibou
# Processing Record 34 of Set 1 | ishigaki
# Processing Record 35 of Set 1 | saint-philippe
# Processing Record 36 of Set 1 | vikulovo
# Processing Record 37 of Set 1 | bonthe
# Processing Record 38 of Set 1 | iracoubo
# Processing Record 39 of Set 1 | bengkulu
# Processing Record 40 of Set 1 | zhigansk
# Processing Record 41 of Set 1 | beni
# Processing Record 42 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 1 | mitu
# Processing Record 44 of Set 1 | portsoy
# Processing Record 45 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 1 | dunedin
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | kant
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | torbay
# Processing Record 2 of Set 2 | tasiilaq
# Processing Record 3 of Set 2 | nizhniy kislyay
# Processing Record 4 of Set 2 | saldanha
# Processing Record 5 of Set 2 | cockburn town
# Processing Record 6 of Set 2 | ribeira grande
# Processing Record 7 of Set 2 | axim
# Processing Record 8 of Set 2 | olga
# Processing Record 9 of Set 2 | uni
# Processing Record 10 of Set 2 | norman wells
# Processing Record 11 of Set 2 | hilo
# Processing Record 12 of Set 2 | manakara
# Processing Record 13 of Set 2 | mandera
# Processing Record 14 of Set 2 | zhaotong
# Processing Record 15 of Set 2 | severo-kurilsk
# Processing Record 16 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 2 | albion
# Processing Record 18 of Set 2 | haines junction
# Processing Record 19 of Set 2 | praia
# Processing Record 20 of Set 2 | busselton
# Processing Record 21 of Set 2 | new norfolk
# Processing Record 22 of Set 2 | taoudenni
# Processing Record 23 of Set 2 | totma
# Processing Record 24 of Set 2 | honningsvag
# Processing Record 25 of Set 2 | alofi
# Processing Record 26 of Set 2 | auki
# Processing Record 27 of Set 2 | airai
# Processing Record 28 of Set 2 | juifang
# City not found. Skipping...
# Processing Record 29 of Set 2 | sao joao da barra
# Processing Record 30 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 31 of Set 2 | albany
# Processing Record 32 of Set 2 | castro
# Processing Record 33 of Set 2 | acarau
# Processing Record 34 of Set 2 | souillac
# Processing Record 35 of Set 2 | luang prabang
# Processing Record 36 of Set 2 | mahebourg
# Processing Record 37 of Set 2 | tuktoyaktuk
# Processing Record 38 of Set 2 | san cristobal
# Processing Record 39 of Set 2 | cidreira
# Processing Record 40 of Set 2 | hermanus
# Processing Record 41 of Set 2 | cabo san lucas
# Processing Record 42 of Set 2 | bukachacha
# Processing Record 43 of Set 2 | athabasca
# Processing Record 44 of Set 2 | sorland
# Processing Record 45 of Set 2 | san patricio
# Processing Record 46 of Set 2 | cherskiy
# Processing Record 47 of Set 2 | punta arenas
# Processing Record 48 of Set 2 | mar del plata
# Processing Record 49 of Set 2 | mahibadhoo
# Processing Record 50 of Set 2 | clyde river
# Processing Record 1 of Set 3 | dharchula
# Processing Record 2 of Set 3 | urumqi
# Processing Record 3 of Set 3 | georgetown
# Processing Record 4 of Set 3 | longyearbyen
# Processing Record 5 of Set 3 | mataura
# Processing Record 6 of Set 3 | pitimbu
# Processing Record 7 of Set 3 | kahului
# Processing Record 8 of Set 3 | nikolskoye
# Processing Record 9 of Set 3 | talnakh
# Processing Record 10 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 3 | astara
# Processing Record 12 of Set 3 | chuy
# Processing Record 13 of Set 3 | ahipara
# Processing Record 14 of Set 3 | chokurdakh
# Processing Record 15 of Set 3 | burns lake
# Processing Record 16 of Set 3 | baykit
# Processing Record 17 of Set 3 | emba
# Processing Record 18 of Set 3 | avarua
# Processing Record 19 of Set 3 | hambantota
# Processing Record 20 of Set 3 | hithadhoo
# Processing Record 21 of Set 3 | coihaique
# Processing Record 22 of Set 3 | puerto ayora
# Processing Record 23 of Set 3 | upernavik
# Processing Record 24 of Set 3 | ginda
# Processing Record 25 of Set 3 | otradnoye
# Processing Record 26 of Set 3 | bethel
# Processing Record 27 of Set 3 | majene
# Processing Record 28 of Set 3 | zheshart
# Processing Record 29 of Set 3 | biltine
# Processing Record 30 of Set 3 | kapaa
# Processing Record 31 of Set 3 | san pedro
# Processing Record 32 of Set 3 | hasaki
# Processing Record 33 of Set 3 | penarroya-pueblonuevo
# Processing Record 34 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 3 | siloam springs
# Processing Record 36 of Set 3 | tura
# Processing Record 37 of Set 3 | asau
# Processing Record 38 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 39 of Set 3 | ponta do sol
# Processing Record 40 of Set 3 | fortuna
# Processing Record 41 of Set 3 | seoul
# Processing Record 42 of Set 3 | qaanaaq
# Processing Record 43 of Set 3 | umm lajj
# Processing Record 44 of Set 3 | mehamn
# Processing Record 45 of Set 3 | dikson
# Processing Record 46 of Set 3 | aksarka
# Processing Record 47 of Set 3 | lazaro cardenas
# Processing Record 48 of Set 3 | kimbe
# Processing Record 49 of Set 3 | flinders
# Processing Record 50 of Set 3 | imeni poliny osipenko
# Processing Record 1 of Set 4 | bredasdorp
# Processing Record 2 of Set 4 | half moon bay
# Processing Record 3 of Set 4 | byumba
# Processing Record 4 of Set 4 | bembibre
# Processing Record 5 of Set 4 | menongue
# Processing Record 6 of Set 4 | andrushivka
# Processing Record 7 of Set 4 | lazo
# Processing Record 8 of Set 4 | port elizabeth
# Processing Record 9 of Set 4 | victoria
# Processing Record 10 of Set 4 | solwezi
# Processing Record 11 of Set 4 | provideniya
# Processing Record 12 of Set 4 | pisco
# Processing Record 13 of Set 4 | ancud
# Processing Record 14 of Set 4 | tahe
# Processing Record 15 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 4 | honiara
# Processing Record 17 of Set 4 | cermik
# Processing Record 18 of Set 4 | narsaq
# Processing Record 19 of Set 4 | diourbel
# Processing Record 20 of Set 4 | arraial do cabo
# Processing Record 21 of Set 4 | champerico
# Processing Record 22 of Set 4 | brae
# Processing Record 23 of Set 4 | wattegama
# Processing Record 24 of Set 4 | geraldton
# Processing Record 25 of Set 4 | ilulissat
# Processing Record 26 of Set 4 | sinop
# Processing Record 27 of Set 4 | hobyo
# Processing Record 28 of Set 4 | taltal
# Processing Record 29 of Set 4 | adrar
# Processing Record 30 of Set 4 | oranjemund
# Processing Record 31 of Set 4 | abha
# Processing Record 32 of Set 4 | yunjinghong
# City not found. Skipping...
# Processing Record 33 of Set 4 | katha
# City not found. Skipping...
# Processing Record 34 of Set 4 | galgani
# City not found. Skipping...
# Processing Record 35 of Set 4 | luohe
# Processing Record 36 of Set 4 | katsuura
# Processing Record 37 of Set 4 | jiuquan
# Processing Record 38 of Set 4 | cap malheureux
# Processing Record 39 of Set 4 | lebu
# Processing Record 40 of Set 4 | natal
# Processing Record 41 of Set 4 | buenos aires
# Processing Record 42 of Set 4 | saint george
# Processing Record 43 of Set 4 | songea
# Processing Record 44 of Set 4 | old saybrook
# Processing Record 45 of Set 4 | namibe
# Processing Record 46 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 4 | najran
# Processing Record 48 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 49 of Set 4 | anadyr
# Processing Record 50 of Set 4 | creston
# Processing Record 1 of Set 5 | byron bay
# Processing Record 2 of Set 5 | tazovskiy
# Processing Record 3 of Set 5 | batagay-alyta
# Processing Record 4 of Set 5 | kualakapuas
# Processing Record 5 of Set 5 | lagoa
# Processing Record 6 of Set 5 | iqaluit
# Processing Record 7 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 8 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 9 of Set 5 | shelburne
# Processing Record 10 of Set 5 | bocanda
# Processing Record 11 of Set 5 | lakes entrance
# Processing Record 12 of Set 5 | ifakara
# Processing Record 13 of Set 5 | ust-nera
# Processing Record 14 of Set 5 | buriti dos lopes
# Processing Record 15 of Set 5 | guaruja
# Processing Record 16 of Set 5 | boyolangu
# Processing Record 17 of Set 5 | faanui
# Processing Record 18 of Set 5 | piranshahr
# Processing Record 19 of Set 5 | suntar
# Processing Record 20 of Set 5 | pangnirtung
# Processing Record 21 of Set 5 | myitkyina
# Processing Record 22 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 24 of Set 5 | tilichiki
# Processing Record 25 of Set 5 | neiafu
# Processing Record 26 of Set 5 | ereymentau
# Processing Record 27 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 28 of Set 5 | yasnyy
# Processing Record 29 of Set 5 | borogontsy
# Processing Record 30 of Set 5 | trapani
# Processing Record 31 of Set 5 | ambilobe
# Processing Record 32 of Set 5 | port hueneme
# Processing Record 33 of Set 5 | kirovskiy
# Processing Record 34 of Set 5 | someshwar
# Processing Record 35 of Set 5 | henties bay
# Processing Record 36 of Set 5 | umm durman
# City not found. Skipping...
# Processing Record 37 of Set 5 | sheridan
# Processing Record 38 of Set 5 | karratha
# Processing Record 39 of Set 5 | kavieng
# Processing Record 40 of Set 5 | jumla
# Processing Record 41 of Set 5 | moron
# Processing Record 42 of Set 5 | korla
# Processing Record 43 of Set 5 | bathurst
# Processing Record 44 of Set 5 | lismore
# Processing Record 45 of Set 5 | leninsk
# Processing Record 46 of Set 5 | vilyuysk
# Processing Record 47 of Set 5 | asfi
# Processing Record 48 of Set 5 | havelock
# Processing Record 49 of Set 5 | manokwari
# Processing Record 50 of Set 5 | zemio
# Processing Record 1 of Set 6 | thompson
# Processing Record 2 of Set 6 | tiksi
# Processing Record 3 of Set 6 | manaure
# Processing Record 4 of Set 6 | bandarbeyla
# Processing Record 5 of Set 6 | kaeo
# Processing Record 6 of Set 6 | nyurba
# Processing Record 7 of Set 6 | kasama
# Processing Record 8 of Set 6 | taiyuan
# Processing Record 9 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 6 | marondera
# Processing Record 11 of Set 6 | palmer
# Processing Record 12 of Set 6 | port hardy
# Processing Record 13 of Set 6 | saint-augustin
# Processing Record 14 of Set 6 | portland
# Processing Record 15 of Set 6 | hvolsvollur
# Processing Record 16 of Set 6 | ulaangom
# Processing Record 17 of Set 6 | saint-joseph
# Processing Record 18 of Set 6 | atbasar
# Processing Record 19 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 20 of Set 6 | huejuquilla el alto
# Processing Record 21 of Set 6 | lebowakgomo
# Processing Record 22 of Set 6 | ihosy
# Processing Record 23 of Set 6 | coos bay
# Processing Record 24 of Set 6 | necochea
# Processing Record 25 of Set 6 | olafsvik
# Processing Record 26 of Set 6 | kavaratti
# Processing Record 27 of Set 6 | port macquarie
# Processing Record 28 of Set 6 | sao filipe
# Processing Record 29 of Set 6 | colgong
# Processing Record 30 of Set 6 | vardo
# Processing Record 31 of Set 6 | russell
# Processing Record 32 of Set 6 | pasni
# Processing Record 33 of Set 6 | nishihara
# Processing Record 34 of Set 6 | vostok
# Processing Record 35 of Set 6 | asaka
# Processing Record 36 of Set 6 | hervey bay
# Processing Record 37 of Set 6 | kulhudhuffushi
# Processing Record 38 of Set 6 | shebunino
# Processing Record 39 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 6 | algiers
# Processing Record 41 of Set 6 | san jose
# Processing Record 42 of Set 6 | bubaque
# Processing Record 43 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 44 of Set 6 | khandyga
# Processing Record 45 of Set 6 | bousso
# Processing Record 46 of Set 6 | matagami
# Processing Record 47 of Set 6 | carndonagh
# Processing Record 48 of Set 6 | le port
# Processing Record 49 of Set 6 | yarke pole
# Processing Record 50 of Set 6 | salalah
# Processing Record 1 of Set 7 | kaitangata
# Processing Record 2 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 7 | sorong
# Processing Record 4 of Set 7 | carutapera
# Processing Record 5 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 6 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 7 of Set 7 | san-pedro
# Processing Record 8 of Set 7 | poitiers
# Processing Record 9 of Set 7 | cervo
# Processing Record 10 of Set 7 | yanchukan
# City not found. Skipping...
# Processing Record 11 of Set 7 | morwa
# Processing Record 12 of Set 7 | fuxin
# Processing Record 13 of Set 7 | crotone
# Processing Record 14 of Set 7 | dingle
# Processing Record 15 of Set 7 | padang
# Processing Record 16 of Set 7 | fare
# Processing Record 17 of Set 7 | codrington
# Processing Record 18 of Set 7 | kaman
# Processing Record 19 of Set 7 | akhalgori
# Processing Record 20 of Set 7 | san policarpo
# Processing Record 21 of Set 7 | nouakchott
# Processing Record 22 of Set 7 | tabou
# Processing Record 23 of Set 7 | achisay
# City not found. Skipping...
# Processing Record 24 of Set 7 | tiznit
# Processing Record 25 of Set 7 | madisonville
# Processing Record 26 of Set 7 | gat
# Processing Record 27 of Set 7 | grand gaube
# Processing Record 28 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 7 | vila franca do campo
# Processing Record 30 of Set 7 | los llanos de aridane
# Processing Record 31 of Set 7 | praia da vitoria
# Processing Record 32 of Set 7 | laguna
# Processing Record 33 of Set 7 | la maddalena
# Processing Record 34 of Set 7 | balkanabat
# Processing Record 35 of Set 7 | hofn
# Processing Record 36 of Set 7 | altay
# Processing Record 37 of Set 7 | pevek
# Processing Record 38 of Set 7 | kapoeta
# Processing Record 39 of Set 7 | atambua
# Processing Record 40 of Set 7 | ambulu
# Processing Record 41 of Set 7 | coruripe
# Processing Record 42 of Set 7 | lorengau
# Processing Record 43 of Set 7 | tutoia
# Processing Record 44 of Set 7 | kenai
# Processing Record 45 of Set 7 | bilma
# Processing Record 46 of Set 7 | mandapam
# Processing Record 47 of Set 7 | leeuwarden
# Processing Record 48 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 7 | broken hill
# Processing Record 50 of Set 7 | lamu
# Processing Record 1 of Set 8 | mayumba
# Processing Record 2 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 3 of Set 8 | hot springs
# Processing Record 4 of Set 8 | guane
# Processing Record 5 of Set 8 | pacific grove
# Processing Record 6 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 8 | stabat
# Processing Record 8 of Set 8 | luba
# Processing Record 9 of Set 8 | guerrero negro
# Processing Record 10 of Set 8 | merauke
# Processing Record 11 of Set 8 | awbari
# Processing Record 12 of Set 8 | raton
# Processing Record 13 of Set 8 | isiolo
# Processing Record 14 of Set 8 | ostrovnoy
# Processing Record 15 of Set 8 | maceio
# Processing Record 16 of Set 8 | liverpool
# Processing Record 17 of Set 8 | cravo norte
# Processing Record 18 of Set 8 | dong hoi
# Processing Record 19 of Set 8 | karakendzha
# City not found. Skipping...
# Processing Record 20 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 21 of Set 8 | chazuta
# Processing Record 22 of Set 8 | kamenka
# Processing Record 23 of Set 8 | paita
# Processing Record 24 of Set 8 | shahrud
# Processing Record 25 of Set 8 | buon me thuot
# City not found. Skipping...
# Processing Record 26 of Set 8 | vestmannaeyjar
# Processing Record 27 of Set 8 | martapura
# Processing Record 28 of Set 8 | richmond
# Processing Record 29 of Set 8 | luderitz
# Processing Record 30 of Set 8 | port hedland
# Processing Record 31 of Set 8 | zarubino
# Processing Record 32 of Set 8 | matamoros
# Processing Record 33 of Set 8 | bairiki
# Processing Record 34 of Set 8 | acapulco
# Processing Record 35 of Set 8 | gamba
# Processing Record 36 of Set 8 | lompoc
# Processing Record 37 of Set 8 | turkistan
# Processing Record 38 of Set 8 | sawtell
# Processing Record 39 of Set 8 | roald
# Processing Record 40 of Set 8 | nsanje
# Processing Record 41 of Set 8 | rawson
# Processing Record 42 of Set 8 | almeirim
# Processing Record 43 of Set 8 | zhanaozen
# Processing Record 44 of Set 8 | fort nelson
# Processing Record 45 of Set 8 | hiroshima
# Processing Record 46 of Set 8 | kysyl-syr
# Processing Record 47 of Set 8 | saba
# Processing Record 48 of Set 8 | rosetown
# Processing Record 49 of Set 8 | hatillo
# Processing Record 50 of Set 8 | beringovskiy
# Processing Record 1 of Set 9 | bathsheba
# Processing Record 2 of Set 9 | yambio
# Processing Record 3 of Set 9 | nkhata bay
# Processing Record 4 of Set 9 | sola
# Processing Record 5 of Set 9 | erattupetta
# Processing Record 6 of Set 9 | gigmoto
# Processing Record 7 of Set 9 | jacareacanga
# Processing Record 8 of Set 9 | talara
# Processing Record 9 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 9 | avera
# Processing Record 11 of Set 9 | kalmunai
# Processing Record 12 of Set 9 | vakhrushev
# Processing Record 13 of Set 9 | cabo rojo
# Processing Record 14 of Set 9 | carauari
# Processing Record 15 of Set 9 | veraval
# Processing Record 16 of Set 9 | teruel
# Processing Record 17 of Set 9 | lavrentiya
# Processing Record 18 of Set 9 | borba
# Processing Record 19 of Set 9 | ribas do rio pardo
# Processing Record 20 of Set 9 | komsomolskiy
# Processing Record 21 of Set 9 | mattru
# Processing Record 22 of Set 9 | saint-quentin
# Processing Record 23 of Set 9 | hokitika
# Processing Record 24 of Set 9 | craig
# Processing Record 25 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 9 | makakilo city
# Processing Record 27 of Set 9 | maniitsoq
# Processing Record 28 of Set 9 | itarema
# Processing Record 29 of Set 9 | krasnyy kommunar
# Processing Record 30 of Set 9 | maine-soroa
# Processing Record 31 of Set 9 | khatanga
# Processing Record 32 of Set 9 | tambilil
# Processing Record 33 of Set 9 | mount gambier
# Processing Record 34 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 9 | tabory
# Processing Record 36 of Set 9 | salas
# Processing Record 37 of Set 9 | poya
# Processing Record 38 of Set 9 | aripuana
# Processing Record 39 of Set 9 | fairbanks
# Processing Record 40 of Set 9 | lukovetskiy
# Processing Record 41 of Set 9 | borama
# City not found. Skipping...
# Processing Record 42 of Set 9 | esperance
# Processing Record 43 of Set 9 | powell river
# Processing Record 44 of Set 9 | ritto
# Processing Record 45 of Set 9 | srednekolymsk
# Processing Record 46 of Set 9 | klaksvik
# Processing Record 47 of Set 9 | borehamwood
# Processing Record 48 of Set 9 | kisanga
# Processing Record 49 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 9 | boende
# Processing Record 1 of Set 10 | leningradskiy
# Processing Record 2 of Set 10 | krasnousolskiy
# City not found. Skipping...
# Processing Record 3 of Set 10 | nador
# Processing Record 4 of Set 10 | andapa
# Processing Record 5 of Set 10 | guymon
# Processing Record 6 of Set 10 | moose factory
# Processing Record 7 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 8 of Set 10 | artsyz
# Processing Record 9 of Set 10 | columbia
# Processing Record 10 of Set 10 | mandalgovi
# Processing Record 11 of Set 10 | nanortalik
# Processing Record 12 of Set 10 | conceicao da barra
# Processing Record 13 of Set 10 | caravelas
# Processing Record 14 of Set 10 | ballina
# Processing Record 15 of Set 10 | yarada
# Processing Record 16 of Set 10 | mugur-aksy
# Processing Record 17 of Set 10 | sergeyevka
# Processing Record 18 of Set 10 | araouane
# Processing Record 19 of Set 10 | umm kaddadah
# Processing Record 20 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 10 | chapais
# Processing Record 22 of Set 10 | isangel
# Processing Record 23 of Set 10 | koungou
# Processing Record 24 of Set 10 | diapaga
# Processing Record 25 of Set 10 | kachiry
# Processing Record 26 of Set 10 | kem
# Processing Record 27 of Set 10 | bayan
# Processing Record 28 of Set 10 | voyvozh
# Processing Record 29 of Set 10 | pimenteiras
# Processing Record 30 of Set 10 | buenaventura
# Processing Record 31 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 32 of Set 10 | omsukchan
# Processing Record 33 of Set 10 | concarneau
# Processing Record 34 of Set 10 | itoman
# Processing Record 35 of Set 10 | torit
# Processing Record 36 of Set 10 | bobcaygeon
# Processing Record 37 of Set 10 | igrim
# Processing Record 38 of Set 10 | sembakung
# Processing Record 39 of Set 10 | fonte boa
# Processing Record 40 of Set 10 | ambon
# Processing Record 41 of Set 10 | surt
# Processing Record 42 of Set 10 | kaili
# Processing Record 43 of Set 10 | tautira
# Processing Record 44 of Set 10 | shieli
# Processing Record 45 of Set 10 | anahuac
# Processing Record 46 of Set 10 | college
# Processing Record 47 of Set 10 | sitka
# Processing Record 48 of Set 10 | northam
# Processing Record 49 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 10 | paamiut
# Processing Record 1 of Set 11 | yerbogachen
# Processing Record 2 of Set 11 | kirensk
# Processing Record 3 of Set 11 | beloha
# Processing Record 4 of Set 11 | kongolo
# Processing Record 5 of Set 11 | raudeberg
# Processing Record 6 of Set 11 | williston
# Processing Record 7 of Set 11 | muyezerskiy
# Processing Record 8 of Set 11 | chihuahua
# Processing Record 9 of Set 11 | oparino
# Processing Record 10 of Set 11 | harlingen
# Processing Record 11 of Set 11 | severobaykalsk
# Processing Record 12 of Set 11 | punto fijo
# Processing Record 13 of Set 11 | wolbrom
# Processing Record 14 of Set 11 | arman
# Processing Record 15 of Set 11 | imbituba
# Processing Record 16 of Set 11 | kaihua
# Processing Record 17 of Set 11 | kerema
# Processing Record 18 of Set 11 | gondar
# Processing Record 19 of Set 11 | nome
# Processing Record 20 of Set 11 | vilhena
# Processing Record 21 of Set 11 | solnechnyy
# Processing Record 22 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 11 | bosaso
# Processing Record 24 of Set 11 | bilgram
# Processing Record 25 of Set 11 | skibbereen
# Processing Record 26 of Set 11 | zhezkazgan
# Processing Record 27 of Set 11 | grindavik
# Processing Record 28 of Set 11 | khed brahma
# Processing Record 29 of Set 11 | borlange
# City not found. Skipping...
# Processing Record 30 of Set 11 | melilla
# Processing Record 31 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 11 | shimoda
# Processing Record 33 of Set 11 | sao borja
# Processing Record 34 of Set 11 | flin flon
# Processing Record 35 of Set 11 | vallenar
# Processing Record 36 of Set 11 | fukue
# Processing Record 37 of Set 11 | alice springs
# Processing Record 38 of Set 11 | whitehorse
# Processing Record 39 of Set 11 | dori
# Processing Record 40 of Set 11 | ulladulla
# Processing Record 41 of Set 11 | chifeng
# Processing Record 42 of Set 11 | port keats
# Processing Record 43 of Set 11 | garhi khairo
# Processing Record 44 of Set 11 | kushima
# Processing Record 45 of Set 11 | pemangkat
# Processing Record 46 of Set 11 | greeneville
# Processing Record 47 of Set 11 | gizo
# Processing Record 48 of Set 11 | kabanjahe
# Processing Record 49 of Set 11 | tocopilla
# Processing Record 50 of Set 11 | aykhal
# Processing Record 1 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 2 of Set 12 | figeac
# Processing Record 3 of Set 12 | terekli-mekteb
# Processing Record 4 of Set 12 | mineiros
# Processing Record 5 of Set 12 | ko samui
# Processing Record 6 of Set 12 | iraray
# Processing Record 7 of Set 12 | santiago de cuba
# Processing Record 8 of Set 12 | marsa matruh
# Processing Record 9 of Set 12 | belyy yar
# Processing Record 10 of Set 12 | khuzhir
# Processing Record 11 of Set 12 | rezh
# Processing Record 12 of Set 12 | psebay
# Processing Record 13 of Set 12 | fecamp
# Processing Record 14 of Set 12 | kawalu
# Processing Record 15 of Set 12 | xinqing
# Processing Record 16 of Set 12 | comodoro rivadavia
# Processing Record 17 of Set 12 | moundsville
# Processing Record 18 of Set 12 | svetlyy
# Processing Record 19 of Set 12 | buraydah
# Processing Record 20 of Set 12 | ust-kut
# Processing Record 21 of Set 12 | sereflikochisar
# Processing Record 22 of Set 12 | darasun
# Processing Record 23 of Set 12 | catamarca
# Processing Record 24 of Set 12 | broome
# Processing Record 25 of Set 12 | sainte-anne
# Processing Record 26 of Set 12 | khategaon
# Processing Record 27 of Set 12 | promyshlennovskiy
# Processing Record 28 of Set 12 | inverell
# Processing Record 29 of Set 12 | burnie
# Processing Record 30 of Set 12 | krasnoselkup
# Processing Record 31 of Set 12 | geylegphug
# City not found. Skipping...
# Processing Record 32 of Set 12 | bahia de caraquez
# Processing Record 33 of Set 12 | ordzhonikidze
# Processing Record 34 of Set 12 | kibondo
# Processing Record 35 of Set 12 | podbelsk
# City not found. Skipping...
# Processing Record 36 of Set 12 | hay river
# Processing Record 37 of Set 12 | nanning
# Processing Record 38 of Set 12 | medea
# Processing Record 39 of Set 12 | moryakovskiy zaton
# Processing Record 40 of Set 12 | kyren
# Processing Record 41 of Set 12 | maues
# Processing Record 42 of Set 12 | yaguajay
# Processing Record 43 of Set 12 | witu
# Processing Record 44 of Set 12 | oktyabrskoye
# Processing Record 45 of Set 12 | wapi pathum
# Processing Record 46 of Set 12 | saint-louis
# Processing Record 47 of Set 12 | martil
# Processing Record 48 of Set 12 | siteki
# Processing Record 49 of Set 12 | lamar
# Processing Record 50 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 13 | iralaya
# Processing Record 2 of Set 13 | isiro
# Processing Record 3 of Set 13 | burica
# City not found. Skipping...
# Processing Record 4 of Set 13 | aklavik
# Processing Record 5 of Set 13 | cairns
# Processing Record 6 of Set 13 | inuvik
# Processing Record 7 of Set 13 | mgandu
# Processing Record 8 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 9 of Set 13 | gaoua
# Processing Record 10 of Set 13 | itupiranga
# Processing Record 11 of Set 13 | nerekhta
# Processing Record 12 of Set 13 | diu
# Processing Record 13 of Set 13 | taua
# Processing Record 14 of Set 13 | smithers
# Processing Record 15 of Set 13 | gilgit
# Processing Record 16 of Set 13 | mpanda
# Processing Record 17 of Set 13 | biak
# Processing Record 18 of Set 13 | kupino
# Processing Record 19 of Set 13 | sayaxche
# Processing Record 20 of Set 13 | scarborough
# Processing Record 21 of Set 13 | yarmouth
# Processing Record 22 of Set 13 | eruwa
# Processing Record 23 of Set 13 | lieksa
# Processing Record 24 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 25 of Set 13 | warsaw
# Processing Record 26 of Set 13 | eatonton
# Processing Record 27 of Set 13 | kholtoson
# Processing Record 28 of Set 13 | vestmanna
# Processing Record 29 of Set 13 | prince rupert
# Processing Record 30 of Set 13 | oksfjord
# Processing Record 31 of Set 13 | okhotsk
# Processing Record 32 of Set 13 | tuatapere
# Processing Record 33 of Set 13 | donskoye
# Processing Record 34 of Set 13 | abu samrah
# Processing Record 35 of Set 13 | tahoua
# Processing Record 36 of Set 13 | woodward
# Processing Record 37 of Set 13 | yalova
# Processing Record 38 of Set 13 | netrakona
# Processing Record 39 of Set 13 | norfolk
# Processing Record 40 of Set 13 | cururupu
# Processing Record 41 of Set 13 | stanovoye
# Processing Record 42 of Set 13 | caramay
# Processing Record 43 of Set 13 | bardiyah
# Processing Record 44 of Set 13 | andenes
# Processing Record 45 of Set 13 | moyobamba
# Processing Record 46 of Set 13 | porto santo
# Processing Record 47 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 48 of Set 13 | lao cai
# Processing Record 49 of Set 13 | port moresby
# Processing Record 50 of Set 13 | kang
# Processing Record 1 of Set 14 | gisborne
# Processing Record 2 of Set 14 | la ronge
# Processing Record 3 of Set 14 | yining
# Processing Record 4 of Set 14 | vidim
# Processing Record 5 of Set 14 | peterborough
# Processing Record 6 of Set 14 | betsiamites
# Processing Record 7 of Set 14 | tessalit
# Processing Record 8 of Set 14 | saint-pierre
# Processing Record 9 of Set 14 | maridi
# Processing Record 10 of Set 14 | poltava
# Processing Record 11 of Set 14 | gulariya
# Processing Record 12 of Set 14 | ketchikan
# Processing Record 13 of Set 14 | beidao
# Processing Record 14 of Set 14 | doha
# Processing Record 15 of Set 14 | nevelsk
# Processing Record 16 of Set 14 | westport
# Processing Record 17 of Set 14 | carmen
# Processing Record 18 of Set 14 | qobustan
# Processing Record 19 of Set 14 | hamilton
# Processing Record 20 of Set 14 | novovasylivka
# Processing Record 21 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 22 of Set 14 | mafeteng
# Processing Record 23 of Set 14 | birjand
# Processing Record 24 of Set 14 | antofagasta
# Processing Record 25 of Set 14 | vila velha
# Processing Record 26 of Set 14 | nizhnyaya tavda
# Processing Record 27 of Set 14 | groningen
# Processing Record 28 of Set 14 | nuuk
# Processing Record 29 of Set 14 | qaqortoq
# Processing Record 30 of Set 14 | yulara
# Processing Record 31 of Set 14 | skjervoy
# Processing Record 32 of Set 14 | zyryanka
# Processing Record 33 of Set 14 | kolokani
# Processing Record 34 of Set 14 | ilo
# Processing Record 35 of Set 14 | kloulklubed
# Processing Record 36 of Set 14 | shirokiy
# Processing Record 37 of Set 14 | richards bay
# Processing Record 38 of Set 14 | loa janan
# Processing Record 39 of Set 14 | launceston
# Processing Record 40 of Set 14 | newport
# Processing Record 41 of Set 14 | samarai
# Processing Record 42 of Set 14 | havre-saint-pierre
# Processing Record 43 of Set 14 | zaltan
# Processing Record 44 of Set 14 | tucuman
# Processing Record 45 of Set 14 | chumikan
# Processing Record 46 of Set 14 | haigerloch
# Processing Record 47 of Set 14 | iwanai
# Processing Record 48 of Set 14 | road town
# Processing Record 49 of Set 14 | leshukonskoye
# Processing Record 50 of Set 14 | mangan
# Processing Record 1 of Set 15 | davila
# Processing Record 2 of Set 15 | nampula
# Processing Record 3 of Set 15 | port lincoln
# Processing Record 4 of Set 15 | roma
# Processing Record 5 of Set 15 | hohhot
# Processing Record 6 of Set 15 | syamzha
# Processing Record 7 of Set 15 | manggar
# Processing Record 8 of Set 15 | kalemie
# Processing Record 9 of Set 15 | west lafayette
# Processing Record 10 of Set 15 | sur
# Processing Record 11 of Set 15 | takoradi
# Processing Record 12 of Set 15 | mount isa
# Processing Record 13 of Set 15 | pacifica
# Processing Record 14 of Set 15 | terrasini
# Processing Record 15 of Set 15 | koslan
# Processing Record 16 of Set 15 | kiama
# Processing Record 17 of Set 15 | pingliang
# Processing Record 18 of Set 15 | uige
# Processing Record 19 of Set 15 | simoes
# Processing Record 20 of Set 15 | hit
# Processing Record 21 of Set 15 | angoche
# Processing Record 22 of Set 15 | rexburg
# Processing Record 23 of Set 15 | jalu
# Processing Record 24 of Set 15 | gotsu
# Processing Record 25 of Set 15 | ferme-neuve
# Processing Record 26 of Set 15 | dawlatabad
# Processing Record 27 of Set 15 | harper
# Processing Record 28 of Set 15 | beaufort
# Processing Record 29 of Set 15 | saurimo
# Processing Record 30 of Set 15 | yeppoon
# Processing Record 31 of Set 15 | herat
# Processing Record 32 of Set 15 | bykivka
# Processing Record 33 of Set 15 | belle fourche
# Processing Record 34 of Set 15 | nanuque
# Processing Record 35 of Set 15 | muros
# Processing Record 36 of Set 15 | nemuro
# Processing Record 37 of Set 15 | coahuayana
# Processing Record 38 of Set 15 | namestovo
# Processing Record 39 of Set 15 | dakar
# Processing Record 40 of Set 15 | faya
# Processing Record 41 of Set 15 | tifton
# Processing Record 42 of Set 15 | lethem
# Processing Record 43 of Set 15 | dukat
# Processing Record 44 of Set 15 | kasongo
# Processing Record 45 of Set 15 | chernyshevskiy
# Processing Record 46 of Set 15 | benalla
# Processing Record 47 of Set 15 | lafia
# Processing Record 48 of Set 15 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 49 of Set 15 | awjilah
# Processing Record 50 of Set 15 | calatagan
# Processing Record 1 of Set 16 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 2 of Set 16 | santa cruz
# Processing Record 3 of Set 16 | gweta
# Processing Record 4 of Set 16 | kazlu ruda
# Processing Record 5 of Set 16 | bowen
# Processing Record 6 of Set 16 | luganville
# Processing Record 7 of Set 16 | veinticinco de mayo
# Processing Record 8 of Set 16 | patacamaya
# Processing Record 9 of Set 16 | lasa
# Processing Record 10 of Set 16 | karlivka
# Processing Record 11 of Set 16 | mnogovershinnyy
# Processing Record 12 of Set 16 | steamboat springs
# Processing Record 13 of Set 16 | clonakilty
# Processing Record 14 of Set 16 | barra patuca
# Processing Record 15 of Set 16 | inderborskiy
# City not found. Skipping...
# Processing Record 16 of Set 16 | lokosovo
# Processing Record 17 of Set 16 | curuca
# Processing Record 18 of Set 16 | fernan-nunez
# Processing Record 19 of Set 16 | ola
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))
# Out:
# 708

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data= pd.DataFrame(city_data)
city_data.head(10)
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Sakaiminato  35.55  133.23     60.80        87          75        9.17
# 1         Coquimbo -29.95  -71.34     55.40        82          75       12.75
# 2          Rikitea -23.12 -134.97     74.62        85          86       22.84
# 3           Atuona  -9.80 -139.03     77.47        79          68       15.12
# 4            Khash  28.22   61.22     40.87        61           0        2.15
# 5      East London -33.02   27.91     65.43        83          73       14.47
# 6           Barrow  71.29 -156.79     28.40        79          90       19.46
# 7  Bambous Virieux -20.34   57.76     69.80        68          40        9.17
# 8     General Roca -39.03  -67.58     89.60        25           0        3.36
# 9             Lata  40.16   -8.33     66.00        92          97        0.69
#
#   Country                 Date
# 0      JP  2020-11-01 23:00:44
# 1      CL  2020-11-01 23:00:44
# 2      PF  2020-11-01 23:00:44
# 3      PF  2020-11-01 23:00:44
# 4      IR  2020-11-01 23:00:44
# 5      ZA  2020-11-01 23:00:44
# 6      US  2020-11-01 22:57:24
# 7      MU  2020-11-01 23:00:45
# 8      AR  2020-11-01 23:00:45
# 9      PT  2020-11-01 23:00:45

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

# %%
city_data = city_data[new_column_order]
city_data
# Out:
#              City Country                 Date    Lat     Lng  Max Temp  \
# 0     Sakaiminato      JP  2020-11-01 23:00:44  35.55  133.23     60.80
# 1        Coquimbo      CL  2020-11-01 23:00:44 -29.95  -71.34     55.40
# 2         Rikitea      PF  2020-11-01 23:00:44 -23.12 -134.97     74.62
# 3          Atuona      PF  2020-11-01 23:00:44  -9.80 -139.03     77.47
# 4           Khash      IR  2020-11-01 23:00:44  28.22   61.22     40.87
# ..            ...     ...                  ...    ...     ...       ...
# 703  Barra Patuca      HN  2020-11-01 22:58:38  15.80  -84.28     79.79
# 704      Lokosovo      RU  2020-11-01 22:58:39  61.13   74.82     29.59
# 705        Curuca      BR  2020-11-01 22:58:39  -0.73  -47.85     78.30
# 706  Fernan-Nunez      ES  2020-11-01 22:58:39  37.69   -4.72     57.20
# 707           Ola      RU  2020-11-01 22:58:39  59.58  151.28     30.06
#
#      Humidity  Cloudiness  Wind Speed
# 0          87          75        9.17
# 1          82          75       12.75
# 2          85          86       22.84
# 3          79          68       15.12
# 4          61           0        2.15
# ..        ...         ...         ...
# 703        85         100        9.51
# 704        97          99       11.83
# 705        84          92        5.64
# 706        82           0        1.12
# 707        93          99        8.32
#
# [708 rows x 9 columns]

# %%
WeatherPy_Database_df = pd.DataFrame(city_data)
WeatherPy_Database_df.to_csv("WeatherPy_Database/WeatherPy_Database.csv", index_label= "city ID")
